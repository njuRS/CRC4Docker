# %% [markdown]
# # Notebook Examples for Chapter 2

# %%
import warnings
# these are innocuous but irritating
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
# %matplotlib inline

# %% [markdown]
# ### Illustrating the central limit theorem

# %%
import numpy as np
import matplotlib.pyplot as plt

r = np.random.rand(10000,12)
array = np.sum(r,1)
p=plt.hist(array,bins=12)

#plt.savefig('/home/mort/LaTeX/new projects/CRC4/Chapter2/fig2_1.eps')

# %% [markdown]
# ### Chi-square density function

# %%
import scipy.stats as st

z = np.linspace(1,20,200)
ax = plt.subplot(111)
for i in range(1,6):
    ax.plot(z,st.chi2.pdf(z,i),label = str(i))
ax.legend()    

#plt.savefig('/home/mort/LaTeX/new projects/CRC4/Chapter2/fig2_2.eps')
# Out:
# e:\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Sampling

# %%
import ee
ee.Initialize()

im = ee.Image(ee.ImageCollection('ASTER/AST_L1T_003') \
            .filterBounds(ee.Geometry.Point([6.5,50.9])) \
            .filterDate('2007-04-30','2007-05-02') \
            .first()) \
            .select('B3N')
roi = ee.Geometry.Polygon(
    [[6.382713317871094,50.90736285477543],
     [6.3961029052734375,50.90130070888041],
     [6.4015960693359375,50.90519789328594],
     [6.388206481933594,50.91169247570916],
     [6.382713317871094,50.90736285477543]])
sample = im.sample(roi,scale=15) \
           .aggregate_array('B3N').getInfo()
p = plt.hist(sample,bins=20)

#plt.savefig('/home/mort/LaTeX/new projects/CRC4/Chapter2/fig2_4.eps')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File e:\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File e:\anaconda3\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File e:\anaconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# TimeoutError: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File e:\anaconda3\lib\site-packages\httplib2shim\__init__.py:140, in Http._conn_request(self, conn, request_uri, method, body, headers)
#     139 try:
# --> 140     urllib3_response = self.pool.request(
#     141         method,
#     142         full_uri,
#     143         body=body,
#     144         headers=headers,
#     145         redirect=False,
#     146         retries=urllib3.Retry(total=False, redirect=0),
#     147         timeout=urllib3.Timeout(total=self.timeout),
#     148         decode_content=decode)
#     150     response = _map_response(urllib3_response, decode=decode)
#
# File e:\anaconda3\lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File e:\anaconda3\lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File e:\anaconda3\lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#
# File e:\anaconda3\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File e:\anaconda3\lib\site-packages\urllib3\util\retry.py:525, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     523 if self.total is False and error:
#     524     # Disabled, indicate to re-raise the error.
# --> 525     raise six.reraise(type(error), error, _stacktrace)
#     527 total = self.total
#
# File e:\anaconda3\lib\site-packages\urllib3\packages\six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File e:\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File e:\anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File e:\anaconda3\lib\site-packages\urllib3\connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    1039 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040     conn.connect()
#    1042 if not conn.is_verified:
#
# File e:\anaconda3\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#
# File e:\anaconda3\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000022F99D2F610>: Failed to establish a new connection: [WinError 10060] 由于连接方在一段时间后没有正确答复或连接的主机没有反应，连接尝试失败。
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# e:\Python_Projects\CRC4Docker\src\Chapter2.ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> import ee
# ----> <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> ee.Initialize()
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> im = ee.Image(ee.ImageCollection('ASTER/AST_L1T_003') \
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>             .filterBounds(ee.Geometry.Point([6.5,50.9])) \
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>             .filterDate('2007-04-30','2007-05-02') \
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>             .first()) \
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>             .select('B3N')
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a> roi = ee.Geometry.Polygon(
#      <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     [[6.382713317871094,50.90736285477543],
#      <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a>      [6.3961029052734375,50.90130070888041],
#      <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>      [6.4015960693359375,50.90519789328594],
#      <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=12'>13</a>      [6.388206481933594,50.91169247570916],
#      <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a>      [6.382713317871094,50.90736285477543]])
#
# File e:\anaconda3\lib\site-packages\ee\__init__.py:132, in Initialize(credentials, opt_url, cloud_api_key, http_transport, project)
#     130 if credentials == 'persistent':
#     131   credentials = data.get_persistent_credentials()
# --> 132 data.initialize(
#     133     credentials=credentials,
#     134     api_base_url=(opt_url + '/api' if opt_url else None),
#     135     tile_base_url=opt_url,
#     136     cloud_api_base_url=opt_url,
#     137     cloud_api_key=cloud_api_key,
#     138     project=project,
#     139     http_transport=http_transport)
#     140 # Initialize the dynamically loaded functions on the objects that want them.
#     141 ApiFunction.initialize()
#
# File e:\anaconda3\lib\site-packages\ee\data.py:201, in initialize(credentials, api_base_url, tile_base_url, cloud_api_base_url, cloud_api_key, project, http_transport)
#     197   _cloud_api_client_version = version
#     199 _http_transport = http_transport
# --> 201 _install_cloud_api_resource()
#     203 if project is not None:
#     204   _cloud_api_user_project = project
#
# File e:\anaconda3\lib\site-packages\ee\data.py:260, in _install_cloud_api_resource()
#     257 global _http_transport
#     259 timeout = (_deadline_ms / 1000.0) or None
# --> 260 _cloud_api_resource = _cloud_api_utils.build_cloud_resource(
#     261     _cloud_api_base_url,
#     262     credentials=_credentials,
#     263     api_key=_cloud_api_key,
#     264     timeout=timeout,
#     265     headers_supplier=_make_request_headers,
#     266     response_inspector=_handle_profiling_response,
#     267     http_transport=_http_transport)
#     269 _cloud_api_resource_raw = _cloud_api_utils.build_cloud_resource(
#     270     _cloud_api_base_url,
#     271     credentials=_credentials,
#    (...)
#     276     http_transport=_http_transport,
#     277     raw=True)
#
# File e:\anaconda3\lib\site-packages\ee\_cloud_api_utils.py:166, in build_cloud_resource(api_base_url, api_key, credentials, timeout, headers_supplier, response_inspector, http_transport, raw)
#     164   pass  # Handle fallback case outside except block, for cleaner stack traces.
#     165 if resource is None:
# --> 166   resource = build()
#     167 resource._baseUrl = api_base_url
#     168 return resource
#
# File e:\anaconda3\lib\site-packages\ee\_cloud_api_utils.py:146, in build_cloud_resource.<locals>.build(**kwargs)
#     145 def build(**kwargs):
# --> 146   return discovery.build(
#     147       'earthengine',
#     148       VERSION,
#     149       discoveryServiceUrl=discovery_service_url,
#     150       developerKey=api_key,
#     151       http=http_transport,
#     152       requestBuilder=request_builder,
#     153       model=alt_model,
#     154       cache_discovery=False,
#     155       **kwargs)
#
# File e:\anaconda3\lib\site-packages\googleapiclient\_helpers.py:134, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     132     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133         logger.warning(message)
# --> 134 return wrapped(*args, **kwargs)
#
# File e:\anaconda3\lib\site-packages\googleapiclient\discovery.py:270, in build(serviceName, version, http, discoveryServiceUrl, developerKey, model, requestBuilder, credentials, cache_discovery, cache, client_options, adc_cert_path, adc_key_path, num_retries)
#     267 requested_url = uritemplate.expand(discovery_url, params)
#     269 try:
# --> 270     content = _retrieve_discovery_doc(
#     271         requested_url,
#     272         discovery_http,
#     273         cache_discovery,
#     274         cache,
#     275         developerKey,
#     276         num_retries=num_retries,
#     277     )
#     278     service = build_from_document(
#     279         content,
#     280         base=discovery_url,
#    (...)
#     288         adc_key_path=adc_key_path,
#     289     )
#     290     break  # exit if a service was created
#
# File e:\anaconda3\lib\site-packages\googleapiclient\discovery.py:376, in _retrieve_discovery_doc(url, http, cache_discovery, cache, developerKey, num_retries)
#     373 # Execute this request with retries build into HttpRequest
#     374 # Note that it will already raise an error if we don't get a 2xx response
#     375 req = HttpRequest(http, HttpRequest.null_postproc, actual_url)
# --> 376 resp, content = req.execute(num_retries=num_retries)
#     378 try:
#     379     content = content.decode("utf-8")
#
# File e:\anaconda3\lib\site-packages\googleapiclient\_helpers.py:134, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     132     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133         logger.warning(message)
# --> 134 return wrapped(*args, **kwargs)
#
# File e:\anaconda3\lib\site-packages\googleapiclient\http.py:900, in HttpRequest.execute(self, http, num_retries)
#     897     self.headers["content-length"] = str(len(self.body))
#     899 # Handle retries for server-side errors.
# --> 900 resp, content = _retry_request(
#     901     http,
#     902     num_retries,
#     903     "request",
#     904     self._sleep,
#     905     self._rand,
#     906     str(self.uri),
#     907     method=str(self.method),
#     908     body=self.body,
#     909     headers=self.headers,
#     910 )
#     912 for callback in self.response_callbacks:
#     913     callback(resp)
#
# File e:\anaconda3\lib\site-packages\googleapiclient\http.py:204, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     202 if exception:
#     203     if retry_num == num_retries:
# --> 204         raise exception
#     205     else:
#     206         continue
#
# File e:\anaconda3\lib\site-packages\googleapiclient\http.py:177, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     175 try:
#     176     exception = None
# --> 177     resp, content = http.request(uri, method, *args, **kwargs)
#     178 # Retry on SSL errors and socket timeout errors.
#     179 except _ssl_SSLError as ssl_error:
#
# File e:\anaconda3\lib\site-packages\google_auth_httplib2.py:209, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     205 # Make a copy of the headers. They will be modified by the credentials
#     206 # and we want to pass the original headers if we recurse.
#     207 request_headers = headers.copy() if headers is not None else {}
# --> 209 self.credentials.before_request(self._request, method, uri, request_headers)
#     211 # Check if the body is a file-like stream, and if so, save the body
#     212 # stream position so that it can be restored in case of refresh.
#     213 body_stream_position = None
#
# File e:\anaconda3\lib\site-packages\google\auth\credentials.py:133, in Credentials.before_request(self, request, method, url, headers)
#     129 # pylint: disable=unused-argument
#     130 # (Subclasses may use these arguments to ascertain information about
#     131 # the http request.)
#     132 if not self.valid:
# --> 133     self.refresh(request)
#     134 self.apply(headers)
#
# File e:\anaconda3\lib\site-packages\google\oauth2\credentials.py:228, in Credentials.refresh(self, request)
#     214     raise exceptions.RefreshError(
#     215         "The credentials do not contain the necessary fields need to "
#     216         "refresh the access token. You must specify refresh_token, "
#     217         "token_uri, client_id, and client_secret."
#     218     )
#     220 scopes = self._scopes if self._scopes is not None else self._default_scopes
#     222 (
#     223     access_token,
#     224     refresh_token,
#     225     expiry,
#     226     grant_response,
#     227     rapt_token,
# --> 228 ) = reauth.refresh_grant(
#     229     request,
#     230     self._token_uri,
#     231     self._refresh_token,
#     232     self._client_id,
#     233     self._client_secret,
#     234     scopes=scopes,
#     235     rapt_token=self._rapt_token,
#     236 )
#     238 self.token = access_token
#     239 self.expiry = expiry
#
# File e:\anaconda3\lib\site-packages\google\oauth2\reauth.py:318, in refresh_grant(request, token_uri, refresh_token, client_id, client_secret, scopes, rapt_token)
#     315 if rapt_token:
#     316     body["rapt"] = rapt_token
# --> 318 response_status_ok, response_data = _client._token_endpoint_request_no_throw(
#     319     request, token_uri, body
#     320 )
#     321 if (
#     322     not response_status_ok
#     323     and response_data.get("error") == _REAUTH_NEEDED_ERROR
#    (...)
#     327     )
#     328 ):
#     329     rapt_token = get_rapt_token(
#     330         request, client_id, client_secret, refresh_token, token_uri, scopes=scopes
#     331     )
#
# File e:\anaconda3\lib\site-packages\google\oauth2\_client.py:115, in _token_endpoint_request_no_throw(request, token_uri, body, access_token, use_json)
#     112 # retry to fetch token for maximum of two times if any internal failure
#     113 # occurs.
#     114 while True:
# --> 115     response = request(method="POST", url=token_uri, headers=headers, body=body)
#     116     response_body = (
#     117         response.data.decode("utf-8")
#     118         if hasattr(response.data, "decode")
#     119         else response.data
#     120     )
#     121     response_data = json.loads(response_body)
#
# File e:\anaconda3\lib\site-packages\google_auth_httplib2.py:119, in Request.__call__(self, url, method, body, headers, timeout, **kwargs)
#     117 try:
#     118     _LOGGER.debug("Making request: %s %s", method, url)
# --> 119     response, data = self.http.request(
#     120         url, method=method, body=body, headers=headers, **kwargs
#     121     )
#     122     return _Response(response, data)
#     123 # httplib2 should catch the lower http error, this is a bug and
#     124 # needs to be fixed there.  Catch the error for the meanwhile.
#
# File e:\anaconda3\lib\site-packages\httplib2\__init__.py:1701, in Http.request(self, uri, method, body, headers, redirections, connection_type)
#    1699             content = b""
#    1700         else:
# -> 1701             (response, content) = self._request(
#    1702                 conn, authority, uri, request_uri, method, body, headers, redirections, cachekey,
#    1703             )
#    1704 except Exception as e:
#    1705     is_timeout = isinstance(e, socket.timeout)
#
# File e:\anaconda3\lib\site-packages\httplib2\__init__.py:1421, in Http._request(self, conn, host, absolute_uri, request_uri, method, body, headers, redirections, cachekey)
#    1418 if auth:
#    1419     auth.request(method, request_uri, headers, body)
# -> 1421 (response, content) = self._conn_request(conn, request_uri, method, body, headers)
#    1423 if auth:
#    1424     if auth.response(response, body):
#
# File e:\anaconda3\lib\site-packages\httplib2shim\__init__.py:154, in Http._conn_request(self, conn, request_uri, method, body, headers)
#     151     content = urllib3_response.data
#     153 except Exception as e:
# --> 154     raise _map_exception(e)
#     156 return response, content
#
# timeout: timed out

# %% [markdown]
# ### Confidence intervals

# %%
from scipy.stats import norm,chi2

def x2(a,m):
    return chi2.ppf(1-a,m)

m = 1000
a = 0.05
g = np.random.random(m)
gbar = np.sum(g)/m
s = np.sum((g-gbar)**2)/(m-1)
print 'sample variance: %f'%s
lower = (m-1)*s/x2(a/2,m-1)
upper = (m-1)*s/x2(1-a/2,m-1)
print '%i percent confidence interval: (%f, %f)'\
               %(int((1-a)*100),lower,upper)
print 'sample mean: %f'%gbar
t = norm.ppf(1-a/2)
sigma = np.sqrt(s)
lower = gbar-t*sigma/np.sqrt(m)
upper = gbar+t*sigma/np.sqrt(m)
print '%i percent confidence interval: (%f, %f)'\
               %(int((1-a)*100),lower,upper)

# %% [markdown]
# ### Provisional means

# %%
from osgeo import gdal
from osgeo.gdalconst import GA_ReadOnly
import auxil.auxil1 as auxil  

gdal.AllRegister()
infile = 'imagery_initial/AST_20070501'               
inDataset = gdal.Open(infile,GA_ReadOnly)     
cols = inDataset.RasterXSize
rows = inDataset.RasterYSize
Xs = np.zeros((cols,3))
cpm = auxil.Cpm(3)
rasterBands=[inDataset.GetRasterBand(k+1)
             for k in range(3)]
for row in range(rows):
    for k in range(3):
        Xs[:,k]=rasterBands[k].ReadAsArray(0,row,cols,1)
    cpm.update(Xs)   
print (cpm.covariance())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# e:\Python_Projects\CRC4Docker\src\Chapter2.ipynb Cell 12 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> from osgeo import gdal
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> from osgeo.gdalconst import GA_ReadOnly
# ----> <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> import auxil.auxil1 as auxil
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> gdal.AllRegister()
#       <a href='vscode-notebook-cell:/e%3A/Python_Projects/CRC4Docker/src/Chapter2.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> infile = 'imagery_initial/AST_20070501'
#
# File e:\Python_Projects\CRC4Docker\src\auxil\auxil1.py:16, in <module>
#      13 import scipy.ndimage.interpolation as ndii
#      15 # wrap the provisional means dll
# ---> 16 lib = ctypes.cdll.LoadLibrary('libprov_means.so')
#      17 provmeans = lib.provmeans
#      18 provmeans.restype = None
#
# File e:\anaconda3\lib\ctypes\__init__.py:460, in LibraryLoader.LoadLibrary(self, name)
#     459 def LoadLibrary(self, name):
# --> 460     return self._dlltype(name)
#
# File e:\anaconda3\lib\ctypes\__init__.py:382, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     379 self._FuncPtr = _FuncPtr
#     381 if handle is None:
# --> 382     self._handle = _dlopen(self._name, mode)
#     383 else:
#     384     self._handle = handle
#
# FileNotFoundError: Could not find module 'libprov_means.so' (or one of its dependencies). Try using the full path with constructor syntax.

# %% [markdown]
# ### Multiple linear regression

# %%
import numpy as np

# biased data matrix X ( 3 independent variables)
X = np.random.rand(100,3)
X = np.mat(np.append(np.ones((100,1)),X,axis=1))
# a parameter vector
w = np.mat([[3.0],[4.0],[5.0],[6.0]])
# noisy dependent variable y with sigma = 0.1
y = X*w+np.random.normal(0,0.1,(100,1))
# pseudoinverse
Xp = (X.T*X).I*X.T
# estimated parameter vector
w = Xp*y
print w
# Out:
#   Input In [9]
#     print w
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(w)?

# %%
import tensorflow as tf

# set up computation graph
X1 = tf.constant(X)
y1 = tf.constant(y)
X1T = tf.transpose(X)
X1p = tf.matmul(tf.matrix_inverse(tf.matmul(X1T,X1)),X1T)
w = tf.matmul(X1p,y1)

# create and run a session to evaluate w 
with tf.Session() as sess:
    w = w.eval()
    
print w

# %%
import ee
ee.Initialize()

# set up JSON description of the calculatiom
X1 = ee.Array(X.tolist())
y1 = ee.Array(y.tolist())
X1T = X1.matrixTranspose()
X1p = X1T.matrixMultiply(X1) \
         .matrixInverse() \
         .matrixMultiply(X1T)
w = X1p.matrixMultiply(y1)

# run on GEE server
print (w.getInfo())

# %%
print 0.01*(X.T*X).I

# %% [markdown]
# ### Mutual information

# %%
import numpy as np
from osgeo import gdal
from osgeo.gdalconst import GA_ReadOnly

def mi(arr1,arr2): 
    '''mutual information of two uint8 arrays '''
    p12 = np.histogram2d(arr1,arr2,bins=256,
                         normed=True)[0].ravel()
    p1  = np.histogram(arr1,bins=256,normed=True)[0]
    p2  = np.histogram(arr2,bins=256,normed=True)[0] 
    p1p2 = np.outer(p1,p2).ravel()    
    idx = p12>0
    return np.sum(p12[idx]*np.log(p12[idx]/p1p2[idx]))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
 
gdal.AllRegister() 
infile = 'imagery/AST_20070501'
            
inDataset = gdal.Open(infile,GA_ReadOnly)     
cols = inDataset.RasterXSize
rows = inDataset.RasterYSize 
image = np.zeros((3,rows*cols)) 
# VNIR bands                                  
for b in range(3):
    band = inDataset.GetRasterBand(b+1)
    image[b,:]=np.byte(band.ReadAsArray(0,0,cols,rows))\
                                              .ravel()
inDataset = None

print mi(image[0,:],image[1,:])
print mi(image[0,:],image[2,:]) 
print mi(image[1,:],image[2,:]) 
# teste kyang
